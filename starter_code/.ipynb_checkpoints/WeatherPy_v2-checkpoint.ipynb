# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
! pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\adamiani\anaconda3\envs\py3_ad\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\adamiani\anaconda3\envs\py3_ad\lib\site-packages (from citipy) (0.16)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json
# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# OpenWeatherMap API Key
api_key = "831bf58f6679f76b8819e7cf9857ce0d"

# %%
output_data_file = pd.read_csv("cities.csv")
output_data_file.head()
# Out:
#    City_ID       City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  ostrovnoy           2      RU  1558378754        72  68.05
# 1        1  mahebourg          75      MU  1558378503        74 -20.41
# 2        2    qaanaaq          25      GL  1558378755        73  77.48
# 3        3     zhuhai           0      CN  1558378755        39  40.71
# 4        4  cape town          20      ZA  1558378755        76 -33.93
#
#       Lng  Max Temp  Wind Speed
# 0   39.51     37.50        7.16
# 1   57.70     78.80       11.41
# 2  -69.36     22.20        2.37
# 3  112.04     44.60        4.47
# 4   18.42     55.99        8.05

# %%
output_data_file.iloc[0:5]
# Out:
#    City_ID       City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  ostrovnoy           2      RU  1558378754        72  68.05
# 1        1  mahebourg          75      MU  1558378503        74 -20.41
# 2        2    qaanaaq          25      GL  1558378755        73  77.48
# 3        3     zhuhai           0      CN  1558378755        39  40.71
# 4        4  cape town          20      ZA  1558378755        76 -33.93
#
#       Lng  Max Temp  Wind Speed
# 0   39.51     37.50        7.16
# 1   57.70     78.80       11.41
# 2  -69.36     22.20        2.37
# 3  112.04     44.60        4.47
# 4   18.42     55.99        8.05

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 605

# %%
city =cities[1]
print(city)
# Out:
# port elizabeth

# %%
url = "http://api.openweathermap.org/data/2.5/weather?&APPID=" + weather_api_key

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?"

# %%
complete_url = base_url + "appid=" + weather_api_key

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
print(weather_api_key)
# Out:
# ldVEZuEeZ1WyQqZMQQPknAJjsyAL7McO

# %%
# Get Weather Data

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
query_url = f"{url}appid={api_key}&units={units}&q="
url = query_url + city

weather_response = requests.get(query_url + city)
weather_json = weather_response.json()
print(json.dumps(weather_json, indent=4))
# Out:
# {
#     "coord": {
#         "lon": 25.57,
#         "lat": -33.92
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 14,
#         "feels_like": 11.13,
#         "temp_min": 14,
#         "temp_max": 14,
#         "pressure": 1023,
#         "humidity": 76
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 4.1,
#         "deg": 50
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1595881538,
#     "sys": {
#         "type": 1,
#         "id": 1973,
#         "country": "ZA",
#         "sunrise": 1595826822,
#         "sunset": 1595864071
#     },
#     "timezone": 7200,
#     "id": 964420,
#     "name": "Port Elizabeth",
#     "cod": 200
# }

# %%
City_ID	City	Cloudiness	Country	Date	Humidity	Lat	Lng	Max Temp	Wind Speed
0	0	ostrovnoy	2	RU	1558378754	72	68.05	39.51	37.50	7.16
1	1	mahebourg	75	MU	1558378503	74	-20.41	57.70	78.80	11.41
2	2	qaanaaq	25	GL	1558378755	73	77.48	-69.36	22.20	2.37
3	3	zhuhai	0	CN	1558378755	39	40.71	112.04	44.60	4.47
4	4	cape town	20	ZA	1558378755	76	-33.93	18.42	55.99	8.05
# Out:
#   File "<ipython-input-12-53529d9bdeac>", line 1
#     City_ID	City	Cloudiness	Country	Date	Humidity	Lat	Lng	Max Temp	Wind Speed
#            	   ^
# SyntaxError: invalid syntax

# %%
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []


count = 1


print(f"Data Processing")
print(f"--------")


for city in cities:  
    

    try: 

        response = requests.get(f"{query_url + city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {count} | {city_record}")
        print(f"{url}&q={city}")
        
    
        count= count + 1
        
       
        time.sleep(1.05)
        

    except:
        print("City not found. Skipping...")
    continue
# Out:
# Data Processing
# --------
# Processing Record 1 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=bredasdorp
# Processing Record 2 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=port elizabeth
# Processing Record 3 | Airai
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=airai
# Processing Record 4 | Vaini
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=vaini
# City not found. Skipping...
# Processing Record 5 | Cherskiy
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=cherskiy
# Processing Record 6 | Mumford
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=mumford
# Processing Record 7 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=ushuaia
# Processing Record 8 | Oron
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=oron
# Processing Record 9 | Busselton
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=busselton
# Processing Record 10 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=upernavik
# Processing Record 11 | Salalah
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=salalah
# City not found. Skipping...
# Processing Record 12 | Morondava
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=morondava
# City not found. Skipping...
# Processing Record 13 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=nikolskoye
# City not found. Skipping...
# Processing Record 14 | Pandan
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=pandan
# City not found. Skipping...
# Processing Record 15 | Alofi
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=alofi
# Processing Record 16 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=kapaa
# Processing Record 17 | Emba
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=emba
# Processing Record 18 | Hobart
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=hobart
# Processing Record 19 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=port alfred
# Processing Record 20 | Castro
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=castro
# Processing Record 21 | Albany
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=albany
# Processing Record 22 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=rikitea
# Processing Record 23 | Rio Verde de Mato Grosso
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=rio verde de mato grosso
# Processing Record 24 | Cidreira
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=cidreira
# Processing Record 25 | Karak
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=karak
# Processing Record 26 | Sitka
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=sitka
# Processing Record 27 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=hermanus
# Processing Record 28 | Torbay
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=torbay
# City not found. Skipping...
# Processing Record 29 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=punta arenas
# Processing Record 30 | Mataura
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=mataura
# Processing Record 31 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=bambous virieux
# Processing Record 32 | Semīrom
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=semirom
# Processing Record 33 | Tura
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=tura
# Processing Record 34 | Lucea
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=lucea
# Processing Record 35 | Palizada
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=palizada
# Processing Record 36 | Shetpe
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=shetpe
# Processing Record 37 | Thompson
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=thompson
# Processing Record 38 | Ol'ga
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=olga
# Processing Record 39 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=cape town
# Processing Record 40 | Bluff
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=bluff
# Processing Record 41 | Mabaruma
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=mabaruma
# City not found. Skipping...
# Processing Record 42 | Leningradskiy
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=leningradskiy
# Processing Record 43 | Avera
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=avera
# Processing Record 44 | San Quintín
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=san quintin
# Processing Record 45 | Trincomalee
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=trincomalee
# Processing Record 46 | Great Yarmouth
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=great yarmouth
# Processing Record 47 | Blackwater
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=blackwater
# Processing Record 48 | General Pico
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=general pico
# Processing Record 49 | Imeni Poliny Osipenko
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=imeni poliny osipenko
# Processing Record 50 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=carnarvon
# Processing Record 51 | Sibolga
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=sibolga
# Processing Record 52 | Morón
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=moron
# Processing Record 53 | Manaus
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=manaus
# Processing Record 54 | Acaraú
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=acarau
# Processing Record 55 | Mayskiy
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=mayskiy
# City not found. Skipping...
# Processing Record 56 | Medeiros Neto
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=medeiros neto
# Processing Record 57 | Russell
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=russell
# Processing Record 58 | Barrow
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=barrow
# Processing Record 59 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=jamestown
# Processing Record 60 | Swan River
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=swan river
# Processing Record 61 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=qaanaaq
# Processing Record 62 | Fortuna
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=fortuna
# Processing Record 63 | Port Hedland
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=port hedland
# Processing Record 64 | Champerico
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=champerico
# Processing Record 65 | Naze
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=naze
# Processing Record 66 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=khatanga
# Processing Record 67 | Dikson
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=dikson
# Processing Record 68 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=tuktoyaktuk
# Processing Record 69 | Mezen'
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=mezen
# Processing Record 70 | Broome
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=broome
# Processing Record 71 | East London
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=east london
# Processing Record 72 | Mackay
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=mackay
# Processing Record 73 | Provideniya
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=provideniya
# Processing Record 74 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=tiksi
# Processing Record 75 | Bindi
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=bindi
# City not found. Skipping...
# Processing Record 76 | Coyhaique
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=coihaique
# Processing Record 77 | Okhotsk
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=okhotsk
# Processing Record 78 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=ribeira grande
# Processing Record 79 | Mosquera
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=mosquera
# Processing Record 80 | Coos Bay
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=coos bay
# Processing Record 81 | Dingle
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=dingle
# Processing Record 82 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=yellowknife
# Processing Record 83 | Guerrero Negro
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=guerrero negro
# Processing Record 84 | Pevek
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=pevek
# City not found. Skipping...
# Processing Record 85 | Arnprior
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=arnprior
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 86 | Inyonga
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=inyonga
# Processing Record 87 | Antalaha
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=antalaha
# Processing Record 88 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=saint-philippe
# Processing Record 89 | Hong Kong
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=victoria
# Processing Record 90 | Linhares
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=linhares
# Processing Record 91 | Atuona
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=atuona
# Processing Record 92 | Yantarnyy
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=yantarnyy
# Processing Record 93 | Kuril'sk
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=kurilsk
# Processing Record 94 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=arraial do cabo
# Processing Record 95 | Troitsko-Pechorsk
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=troitsko-pechorsk
# Processing Record 96 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=hithadhoo
# Processing Record 97 | Iqaluit
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=iqaluit
# City not found. Skipping...
# Processing Record 98 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=ponta do sol
# City not found. Skipping...
# Processing Record 99 | Katsuura
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=katsuura
# Processing Record 100 | Chui
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=chuy
# Processing Record 101 | Hilo
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=hilo
# Processing Record 102 | Rosarito
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=rosarito
# Processing Record 103 | El Pueblito
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=el pueblito
# Processing Record 104 | Hanmer Springs
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=hanmer springs
# City not found. Skipping...
# Processing Record 105 | Crestview
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=crestview
# Processing Record 106 | Ubari
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=awbari
# Processing Record 107 | Yangi Marg`ilon
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=komsomolskiy
# Processing Record 108 | Saint Paul Harbor
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=kodiak
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 109 | Sur
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=sur
# Processing Record 110 | Băleşti
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=balesti
# City not found. Skipping...
# Processing Record 111 | Nukus
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=nukus
# Processing Record 112 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=longyearbyen
# Processing Record 113 | Innisfail
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=innisfail
# Processing Record 114 | Mahébourg
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=mahebourg
# Processing Record 115 | Las Choapas
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=las choapas
# Processing Record 116 | Linqing
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=linqing
# Processing Record 117 | Sol'tsy
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=soltsy
# Processing Record 118 | Chapais
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=chapais
# Processing Record 119 | Closepet
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=ramanagaram
# Processing Record 120 | Nyrob
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=nyrob
# Processing Record 121 | Ondjiva
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=ondjiva
# Processing Record 122 | Codrington
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=codrington
# Processing Record 123 | Manaure
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=manaure
# Processing Record 124 | Rawson
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=rawson
# Processing Record 125 | Eureka
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=eureka
# Processing Record 126 | Malbork
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=marienburg
# City not found. Skipping...
# Processing Record 127 | Camacha
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=camacha
# Processing Record 128 | Lagoa
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=lagoa
# Processing Record 129 | Kristinestad
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=kristiinankaupunki
# City not found. Skipping...
# Processing Record 130 | Fare
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=fare
# City not found. Skipping...
# Processing Record 131 | Acapulco de Juárez
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=acapulco
# City not found. Skipping...
# Processing Record 132 | Cabo San Lucas
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=cabo san lucas
# Processing Record 133 | Lompoc
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=lompoc
# Processing Record 134 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=puerto ayora
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 135 | Carmo
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=carmo
# Processing Record 136 | Yakeshi
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=yakeshi
# Processing Record 137 | Mandalgovi
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=mandalgovi
# Processing Record 138 | Bubaque
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=bubaque
# Processing Record 139 | Lerum
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=lerum
# Processing Record 140 | Kadipaten
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=kadipaten
# Processing Record 141 | Constitución
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=constitucion
# Processing Record 142 | Shawnee
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=shawnee
# Processing Record 143 | Taltal
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=taltal
# Processing Record 144 | Matara
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=matara
# Processing Record 145 | Totness
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=totness
# Processing Record 146 | Lukovetskiy
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=lukovetskiy
# Processing Record 147 | Erzin
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=erzin
# Processing Record 148 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=mar del plata
# Processing Record 149 | Saskylakh
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=saskylakh
# Processing Record 150 | Zhangye
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=zhangye
# Processing Record 151 | Kawalu
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=kawalu
# Processing Record 152 | Ilulissat
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=ilulissat
# Processing Record 153 | Vilhena
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=vilhena
# Processing Record 154 | Abu Dhabi
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=abu dhabi
# City not found. Skipping...
# Processing Record 155 | Siderno
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=siderno
# Processing Record 156 | Ludza
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=ludza
# Processing Record 157 | Konosha
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=konosha
# Processing Record 158 | Lata
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=lata
# Processing Record 159 | Karratha
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=karratha
# Processing Record 160 | Esmeralda
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=esmeralda
# Processing Record 161 | Senneterre
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=senneterre
# Processing Record 162 | Lenzburg
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=lenzburg
# Processing Record 163 | Vaitape
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=vaitape
# Processing Record 164 | Sindor
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=sindor
# Processing Record 165 | Rio Grande
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=rio grande
# Processing Record 166 | Hualmay
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=hualmay
# Processing Record 167 | Saint George
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=saint george
# Processing Record 168 | Itarema
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=itarema
# Processing Record 169 | Flinders
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=flinders
# Processing Record 170 | Jimo
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=jimo
# Processing Record 171 | Anadyr
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=anadyr
# Processing Record 172 | Emerald
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=emerald
# Processing Record 173 | Ardakān
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=ardakan
# Processing Record 174 | Nefteyugansk
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=nefteyugansk
# Processing Record 175 | Kongolo
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=kongolo
# Processing Record 176 | Eskilstuna
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=eskilstuna
# Processing Record 177 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=new norfolk
# Processing Record 178 | São José da Coroa Grande
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=sao jose da coroa grande
# Processing Record 179 | Leça da Palmeira
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=leca da palmeira
# Processing Record 180 | Talnakh
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=talnakh
# Processing Record 181 | Ambilobe
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=ambilobe
# Processing Record 182 | San Patricio
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=san patricio
# Processing Record 183 | Billings Metropolitan Area
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=billings
# Processing Record 184 | Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=chokurdakh
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 185 | Vardø
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=vardo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 186 | Tautira
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=tautira
# Processing Record 187 | Baykit
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=baykit
# Processing Record 188 | Chengde
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=chengde
# Processing Record 189 | Heihe
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=heihe
# Processing Record 190 | Caravelas
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=caravelas
# Processing Record 191 | Asadābād
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=asadabad
# Processing Record 192 | Buala
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=buala
# Processing Record 193 | Faanui
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=faanui
# Processing Record 194 | Nome
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=nome
# Processing Record 195 | Raja
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=raga
# Processing Record 196 | Cibitoke Province
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=cibitoke
# Processing Record 197 | Kananga
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=kananga
# Processing Record 198 | Sokolo
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=sokolo
# Processing Record 199 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=butaritari
# City not found. Skipping...
# Processing Record 200 | Prince George
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=prince george
# Processing Record 201 | Lufilufi
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=lufilufi
# Processing Record 202 | Lamlash
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=lamlash
# Processing Record 203 | Porto-Novo
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=porto novo
# Processing Record 204 | Caraballeda
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=caraballeda
# Processing Record 205 | Oga
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=oga
# Processing Record 206 | Podosinovets
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=podosinovets
# Processing Record 207 | Jieshi
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=jieshi
# Processing Record 208 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=kaitangata
# Processing Record 209 | Ahipara
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=ahipara
# Processing Record 210 | Kouroussa
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=kouroussa
# Processing Record 211 | Aklavik
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=aklavik
# Processing Record 212 | Hasaki
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=hasaki
# Processing Record 213 | Subiaco
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=subiaco
# Processing Record 214 | Kandi
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=kandi
# Processing Record 215 | Saldanha
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=saldanha
# Processing Record 216 | Najrān
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=najran
# Processing Record 217 | Bengkulu
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=bengkulu
# Processing Record 218 | Araouane
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=araouane
# Processing Record 219 | Klaksvík
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=klaksvik
# Processing Record 220 | Farim
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=farim
# Processing Record 221 | Fort Nelson
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=fort nelson
# Processing Record 222 | Mârzăneşti
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=marzanesti
# Processing Record 223 | Porbandar
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=porbandar
# Processing Record 224 | Kimbe
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=kimbe
# Processing Record 225 | Olafsvik
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=olafsvik
# Processing Record 226 | Grindavik
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=grindavik
# Processing Record 227 | Epe
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=epe
# Processing Record 228 | Broken Hill
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=broken hill
# Processing Record 229 | Gaoua
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=gaoua
# Processing Record 230 | Pilar
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=pilar
# City not found. Skipping...
# Processing Record 231 | Lima
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=lima
# Processing Record 232 | Fort Frances
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=fort frances
# Processing Record 233 | Mossamedes
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=namibe
# City not found. Skipping...
# Processing Record 234 | Hervey Bay
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=hervey bay
# Processing Record 235 | Sisa
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=san jose de sisa
# Processing Record 236 | Goderich
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=goderich
# Processing Record 237 | Tiarei
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=tiarei
# Processing Record 238 | Kathmandu
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=kathmandu
# Processing Record 239 | Port Maria
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=port maria
# Processing Record 240 | Cayenne
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=cayenne
# Processing Record 241 | Mizdah
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=mizdah
# Processing Record 242 | Coquimbo
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=coquimbo
# City not found. Skipping...
# Processing Record 243 | Kavieng
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=kavieng
# Processing Record 244 | George
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=george
# Processing Record 245 | Alappuzha
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=alappuzha
# Processing Record 246 | Monrovia
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=monrovia
# Processing Record 247 | Santa Cruz de La Palma
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=santa cruz de la palma
# Processing Record 248 | Isugod
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=isugod
# Processing Record 249 | Paraná
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=parana
# Processing Record 250 | Si Bun Rueang
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=si bun ruang
# Processing Record 251 | Severo-Kuril'sk
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=severo-kurilsk
# Processing Record 252 | Bang Saphan
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=bang saphan
# Processing Record 253 | Half Moon Bay
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=half moon bay
# Processing Record 254 | Östersund
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=ostersund
# Processing Record 255 | Mocorito
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=mocorito
# Processing Record 256 | Kerman
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=kerman
# Processing Record 257 | Kalemie
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=kalemie
# Processing Record 258 | Avarua
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=avarua
# Processing Record 259 | Sosnovskoye
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=sosnovskoye
# Processing Record 260 | Thiadiaye
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=thiadiaye
# Processing Record 261 | Dunedin
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=dunedin
# Processing Record 262 | Pangody
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=pangody
# Processing Record 263 | Narasannapeta
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=narasannapeta
# Processing Record 264 | Dali
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=dali
# Processing Record 265 | Balkanabat
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=balkanabat
# Processing Record 266 | Kaduqli
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=kaduqli
# Processing Record 267 | Irmo
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=irmo
# Processing Record 268 | Zima
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=zima
# Processing Record 269 | Killybegs
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=killybegs
# Processing Record 270 | Lichinga
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=lichinga
# Processing Record 271 | Rafrāf
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=rafraf
# Processing Record 272 | Laguna
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=laguna
# Processing Record 273 | Sittwe
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=akyab
# Processing Record 274 | Clyde River
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=clyde river
# Processing Record 275 | Sumenep
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=sumenep
# City not found. Skipping...
# Processing Record 276 | Kandiari
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=kandiari
# Processing Record 277 | Paamiut
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=paamiut
# Processing Record 278 | Madimba
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=madimba
# Processing Record 279 | Ketchikan
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=ketchikan
# Processing Record 280 | Lovington
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=lovington
# Processing Record 281 | Kismayo
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=kismayo
# Processing Record 282 | Pāsighāt
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=pasighat
# Processing Record 283 | Daşoguz
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=dasoguz
# Processing Record 284 | George Town
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=georgetown
# Processing Record 285 | Auki
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=auki
# Processing Record 286 | Pacific Grove
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=pacific grove
# Processing Record 287 | Tateyama
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=tateyama
# Processing Record 288 | Geraldton
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=geraldton
# Processing Record 289 | Cornwall
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=cornwall
# Processing Record 290 | Mahon
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=mao
# Processing Record 291 | Lebu
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=lebu
# Processing Record 292 | Pangnirtung
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=pangnirtung
# Processing Record 293 | Andenes
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=andenes
# Processing Record 294 | Bara
# ...
# City not found. Skipping...
# Processing Record 455 | Honningsvåg
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=honningsvag
# Processing Record 456 | Rūdsar
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=rudsar
# Processing Record 457 | Prata
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=prata
# City not found. Skipping...
# Processing Record 458 | Gao
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=gao
# Processing Record 459 | Skagen
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=skagen
# Processing Record 460 | Monte Patria
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=monte patria
# Processing Record 461 | Narrabri
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=narrabri
# Processing Record 462 | San Jose
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=san jose
# Processing Record 463 | Chabahar
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=chabahar
# Processing Record 464 | Inhambane
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=inhambane
# Processing Record 465 | Pipili
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=pipili
# Processing Record 466 | Port Moresby
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=port moresby
# Processing Record 467 | Coffeyville
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=coffeyville
# City not found. Skipping...
# Processing Record 468 | Haridwar
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=haridwar
# Processing Record 469 | Praia
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=praia
# Processing Record 470 | Manta
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=manta
# Processing Record 471 | Naryan-Mar
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=naryan-mar
# Processing Record 472 | Muhafazat Lahij
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=lahij
# Processing Record 473 | Takoradze
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=takoradi
# Processing Record 474 | Ust-Nera
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=ust-nera
# Processing Record 475 | Darya Khan
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=darya khan
# Processing Record 476 | Tromsø
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=tromso
# Processing Record 477 | Turukhansk
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=turukhansk
# Processing Record 478 | Sosnovo-Ozerskoye
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=sosnovo-ozerskoye
# Processing Record 479 | Crotone
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=crotone
# Processing Record 480 | Aubenas
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=aubenas
# Processing Record 481 | Binabalian Ricor
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=binabalian
# Processing Record 482 | Kloulklubed
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=kloulklubed
# Processing Record 483 | Boa Vista
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=boa vista
# Processing Record 484 | Senador José Porfírio
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=senador jose porfirio
# Processing Record 485 | Domoni
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=domoni
# Processing Record 486 | Kachīry
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=kachiry
# Processing Record 487 | Province of Mantua
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=mantua
# Processing Record 488 | Phan Thiet
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=phan thiet
# Processing Record 489 | Santa Vitória do Palmar
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=santa vitoria do palmar
# Processing Record 490 | Kadoma
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=kadoma
# Processing Record 491 | Le Kremlin-Bicêtre
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=le kremlin-bicetre
# Processing Record 492 | Suleja
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=suleja
# Processing Record 493 | Baft
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=baft
# Processing Record 494 | Seoul
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=seoul
# Processing Record 495 | Tartagal
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=tartagal
# Processing Record 496 | Calvinia
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=calvinia
# Processing Record 497 | Dawei
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=dawei
# Processing Record 498 | Nelson Bay
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=nelson bay
# Processing Record 499 | Xinxiang
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=xinxiang
# Processing Record 500 | São João da Barra
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=sao joao da barra
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 501 | Baraboo
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=baraboo
# Processing Record 502 | Moa
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=moa
# Processing Record 503 | Nantai
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=nantai
# Processing Record 504 | Pāveh
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=paveh
# Processing Record 505 | Petropavlovka
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=petropavlovka
# Processing Record 506 | Ferme-Neuve
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=ferme-neuve
# Processing Record 507 | Kindu
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=kindu
# Processing Record 508 | Qaqortoq
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=qaqortoq
# Processing Record 509 | Haines Junction
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=haines junction
# Processing Record 510 | Keningau
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=keningau
# Processing Record 511 | Boguchany
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=boguchany
# Processing Record 512 | Shizunai-furukawachō
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=shizunai
# Processing Record 513 | Roald
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=roald
# Processing Record 514 | Biak
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=biak
# Processing Record 515 | Bonavista
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=bonavista
# Processing Record 516 | Jequitinhonha
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=jequitinhonha
# City not found. Skipping...
# Processing Record 517 | Topchānchi
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=topchanchi
# Processing Record 518 | Darhan
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=darhan
# Processing Record 519 | Chicama
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=chicama
# Processing Record 520 | Villa de Cura
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=villa de cura
# Processing Record 521 | Vila Franca do Campo
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=vila franca do campo
# Processing Record 522 | Knysna
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=knysna
# Processing Record 523 | Hokitika
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=hokitika
# Processing Record 524 | Warrington
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=warrington
# Processing Record 525 | Manuk Mangkaw
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=manuk mangkaw
# Processing Record 526 | Mumbwa
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=mumbwa
# Processing Record 527 | Mahibadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=mahibadhoo
# Processing Record 528 | Aransas Pass
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=aransas pass
# Processing Record 529 | Nuuk
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=nuuk
# Processing Record 530 | Kudahuvadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=kudahuvadhoo
# Processing Record 531 | Comodoro Rivadavia
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=comodoro rivadavia
# City not found. Skipping...
# Processing Record 532 | Lieksa
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=lieksa
# Processing Record 533 | Chimbarongo
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=chimbarongo
# Processing Record 534 | Pangai
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=pangai
# Processing Record 535 | Waingapu
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=waingapu
# Processing Record 536 | Nyurba
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=nyurba
# Processing Record 537 | Maralal
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=maralal
# Processing Record 538 | Lagan
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=kaspiyskiy
# Processing Record 539 | Culebra
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=culebra
# Processing Record 540 | Río Gallegos
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=rio gallegos
# Processing Record 541 | Bocas del Toro
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=bocas del toro
# Processing Record 542 | Sarangani
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=sarangani
# Processing Record 543 | Abrau-Dyurso
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=abrau-dyurso
# Processing Record 544 | Kaputa
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=kaputa
# Processing Record 545 | Manavālakurichi
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=manavalakurichi
# Processing Record 546 | Vila
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=vila
# Processing Record 547 | Canguaretama
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=canguaretama
# Processing Record 548 | Cabedelo
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=cabedelo
# City not found. Skipping...
# Processing Record 549 | Berlevåg
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=berlevag
# Processing Record 550 | Starkville
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=starkville
# Processing Record 551 | Mulanje
# http://api.openweathermap.org/data/2.5/weather?appid=831bf58f6679f76b8819e7cf9857ce0d&units=metric&q=port elizabeth&q=mulanje

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# %%
city_data = {"City": city_name, 
                          "Lat": lat, 
                          "Lng": lng, 
                          "Max Temp": max_temp,
                          "Humidity": humidity,
                          "Cloudiness": cloudiness,
                          "Wind Speed": wind_speed,
                          "Country": country,
                          "Date": date}

# %%
df2 = pd.DataFrame(city_data)

# %%
df2.head()
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Bredasdorp -34.53   20.04      9.00        87           0        1.50
# 1  Port Elizabeth -33.92   25.57     14.00        76           0        4.10
# 2           Airai  -8.93  125.41     11.35        95          87        1.50
# 3           Vaini -21.20 -175.20     22.00        83          20        5.10
# 4        Cherskiy  68.75  161.30      6.33        63          38        4.51
#
#   Country        Date
# 0      ZA  1595881858
# 1      ZA  1595881538
# 2      TL  1595881860
# 3      TO  1595881861
# 4      RU  1595881863

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
