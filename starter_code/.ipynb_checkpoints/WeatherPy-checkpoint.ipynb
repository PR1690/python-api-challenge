# %% [markdown]
# # WeatherPy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import scipy.stats as st
import json

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
output_data_file = pd.read_csv("../output_data/cities.csv")
output_data_file
# Out:
#      Unnamed: 0           City  Cloudiness Country        Date  Humidity  \
# 0             0    tuktoyaktuk          90      CA  1595985103        93
# 1             1   quatre cocos          20      MU  1595985488        83
# 2             2     port pirie           0      AU  1595985488        48
# 3             3         rafraf          20      TN  1595985488        53
# 4             4  cockburn town          14      TC  1595985488        81
# ..          ...            ...         ...     ...         ...       ...
# 561         561   beringovskiy          20      RU  1595985134        59
# 562         562    san quintin           1      MX  1595985162        74
# 563         563        padilla          40      CO  1595985523        69
# 564         564        te anau         100      NZ  1595985523        83
# 565         565        milkovo         100      RU  1595985523        48
#
#       Temp    Lat     Lng  Wind Speed
# 0    48.20  69.45 -133.04       10.29
# 1    69.80 -20.21   57.76        4.70
# 2    60.80 -33.18  138.02        9.17
# 3    73.40  37.19   10.18        3.36
# 4    83.28  21.46  -71.14       19.77
# ..     ...    ...     ...         ...
# 561  62.33  63.05  179.32        9.93
# 562  69.75  30.48 -115.95       16.98
# 563  75.20   3.22  -76.31        5.82
# 564  49.26 -45.42  167.72        1.45
# 565  73.99  54.72  158.62        2.26
#
# [566 rows x 10 columns]

# %% [markdown]
# ## Generate Cities List

# %%
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 604

# %%
url = "http://api.openweathermap.org/data/2.5/forecast?id=524901&APPID="
target_url = url + weather_api_key
target_url
# Out:
# 'http://api.openweathermap.org/data/2.5/forecast?id=524901&APPID=1552e63a9c97f14feea359d3e9866f97'

# %%
# set up lists to hold reponse info
cityname = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []
count = 0

#  response = requests.get(query_url + city).json()
    
# Loop through the list of cities and perform a request for data on each

for city in cities:
    weather_response = requests.get(target_url + "&q=" + city + "&units=Imperial")
    weather_json = weather_response.json()
    try:
        cityname.append(weather_json['city']['name'])
        cloudiness.append(weather_json['list'][0]['clouds']['all'])
        country.append(weather_json['city']['country'])
        date.append(weather_json['list'][0]['dt'])
        humidity.append(weather_json['list'][0]['main']['humidity'])
        lat.append(weather_json['city']['coord']['lat'])
        lng.append(weather_json['city']['coord']['lon'])
        max_temp.append(weather_json['list'][0]['main']['temp_max'])
        wind_speed.append(weather_json['list'][0]['wind']['speed'])
        count = count + 1
        print(f"Processing record {count} of Set 1 | {city}")
    except:
        print("Record not found") 
        pass
# Out:
# Processing record 1 of Set 1 | ribeira grande
# Processing record 2 of Set 1 | berlevag
# Processing record 3 of Set 1 | punta arenas
# Processing record 4 of Set 1 | mnogovershinnyy
# Processing record 5 of Set 1 | bathsheba
# Processing record 6 of Set 1 | katsuura
# Processing record 7 of Set 1 | mataura
# Processing record 8 of Set 1 | texarkana
# Processing record 9 of Set 1 | meulaboh
# Processing record 10 of Set 1 | qaanaaq
# Processing record 11 of Set 1 | yellowknife
# Processing record 12 of Set 1 | georgetown
# Processing record 13 of Set 1 | camacha
# Processing record 14 of Set 1 | albany
# Processing record 15 of Set 1 | kapaa
# Processing record 16 of Set 1 | dandong
# Record not found
# Processing record 17 of Set 1 | kwekwe
# Processing record 18 of Set 1 | barrow
# Processing record 19 of Set 1 | saint johnsbury
# Processing record 20 of Set 1 | kavieng
# Processing record 21 of Set 1 | bredasdorp
# Record not found
# Processing record 22 of Set 1 | visnes
# Processing record 23 of Set 1 | troitsko-pechorsk
# Processing record 24 of Set 1 | gravelbourg
# Processing record 25 of Set 1 | cidreira
# Processing record 26 of Set 1 | samarai
# Processing record 27 of Set 1 | rikitea
# Processing record 28 of Set 1 | iqaluit
# Processing record 29 of Set 1 | vaini
# Processing record 30 of Set 1 | nhulunbuy
# Processing record 31 of Set 1 | harper
# Processing record 32 of Set 1 | ushuaia
# Processing record 33 of Set 1 | esperance
# Processing record 34 of Set 1 | port alfred
# Record not found
# Record not found
# Processing record 35 of Set 1 | camopi
# Processing record 36 of Set 1 | kokstad
# Processing record 37 of Set 1 | airai
# Processing record 38 of Set 1 | port blair
# Processing record 39 of Set 1 | castro
# Processing record 40 of Set 1 | bridlington
# Processing record 41 of Set 1 | dakoro
# Processing record 42 of Set 1 | upernavik
# Processing record 43 of Set 1 | new norfolk
# Processing record 44 of Set 1 | hobart
# Processing record 45 of Set 1 | inongo
# Processing record 46 of Set 1 | quatre cocos
# Processing record 47 of Set 1 | pevek
# Processing record 48 of Set 1 | thompson
# Processing record 49 of Set 1 | ancud
# Processing record 50 of Set 1 | jutai
# Processing record 51 of Set 1 | mar del plata
# Processing record 52 of Set 1 | nikolskoye
# Processing record 53 of Set 1 | vinh
# Processing record 54 of Set 1 | isangel
# Processing record 55 of Set 1 | grindavik
# Processing record 56 of Set 1 | north bay
# Processing record 57 of Set 1 | pacific grove
# Processing record 58 of Set 1 | hermanus
# Processing record 59 of Set 1 | santa catarina
# Record not found
# Processing record 60 of Set 1 | faanui
# Processing record 61 of Set 1 | fairbanks
# Processing record 62 of Set 1 | kavaratti
# Processing record 63 of Set 1 | norman wells
# Processing record 64 of Set 1 | arraial do cabo
# Processing record 65 of Set 1 | trat
# Processing record 66 of Set 1 | hithadhoo
# Processing record 67 of Set 1 | thinadhoo
# Processing record 68 of Set 1 | jiangyou
# Processing record 69 of Set 1 | kahului
# Processing record 70 of Set 1 | tasiilaq
# Processing record 71 of Set 1 | rawson
# Record not found
# Processing record 72 of Set 1 | bethel
# Processing record 73 of Set 1 | ugoofaaru
# Processing record 74 of Set 1 | gurmatkal
# Record not found
# Processing record 75 of Set 1 | cape town
# Processing record 76 of Set 1 | byron bay
# Processing record 77 of Set 1 | avarua
# Processing record 78 of Set 1 | hede
# Processing record 79 of Set 1 | lorengau
# Processing record 80 of Set 1 | bluff
# Processing record 81 of Set 1 | barstow
# Processing record 82 of Set 1 | lazaro cardenas
# Processing record 83 of Set 1 | constantine
# Processing record 84 of Set 1 | ambilobe
# Processing record 85 of Set 1 | hofn
# Processing record 86 of Set 1 | puerto ayora
# Processing record 87 of Set 1 | atuona
# Processing record 88 of Set 1 | santiago del estero
# Processing record 89 of Set 1 | atambua
# Record not found
# Processing record 90 of Set 1 | groningen
# Processing record 91 of Set 1 | sitka
# Processing record 92 of Set 1 | la ronge
# Processing record 93 of Set 1 | mitchell
# Processing record 94 of Set 1 | kaitangata
# Processing record 95 of Set 1 | guaratinga
# Processing record 96 of Set 1 | belaya gora
# Processing record 97 of Set 1 | lagoa
# Processing record 98 of Set 1 | ronne
# Processing record 99 of Set 1 | bull savanna
# Processing record 100 of Set 1 | itaituba
# Processing record 101 of Set 1 | saint george
# Processing record 102 of Set 1 | virginia beach
# Processing record 103 of Set 1 | tessalit
# Processing record 104 of Set 1 | bambous virieux
# Processing record 105 of Set 1 | caravelas
# Processing record 106 of Set 1 | geraldton
# Processing record 107 of Set 1 | naze
# Processing record 108 of Set 1 | kadnikov
# Processing record 109 of Set 1 | avera
# Processing record 110 of Set 1 | severo-kurilsk
# Processing record 111 of Set 1 | beloha
# Processing record 112 of Set 1 | olafsvik
# Processing record 113 of Set 1 | gornyye klyuchi
# Processing record 114 of Set 1 | hilo
# Processing record 115 of Set 1 | salalah
# Processing record 116 of Set 1 | west bay
# Processing record 117 of Set 1 | busselton
# Processing record 118 of Set 1 | derzhavinsk
# Processing record 119 of Set 1 | comodoro rivadavia
# Processing record 120 of Set 1 | palasa
# Processing record 121 of Set 1 | pacov
# Record not found
# Processing record 122 of Set 1 | batemans bay
# Processing record 123 of Set 1 | luanda
# Processing record 124 of Set 1 | itambe
# Processing record 125 of Set 1 | almeirim
# Processing record 126 of Set 1 | rajapur
# Processing record 127 of Set 1 | carnarvon
# Processing record 128 of Set 1 | butaritari
# Processing record 129 of Set 1 | la palma
# Processing record 130 of Set 1 | kennett
# Record not found
# Processing record 131 of Set 1 | rongcheng
# Processing record 132 of Set 1 | nur
# Processing record 133 of Set 1 | yar-sale
# Processing record 134 of Set 1 | abaza
# Processing record 135 of Set 1 | moose factory
# Processing record 136 of Set 1 | kaka
# Processing record 137 of Set 1 | nemuro
# Record not found
# Processing record 138 of Set 1 | chokurdakh
# Processing record 139 of Set 1 | uddevalla
# Processing record 140 of Set 1 | vulturu
# Processing record 141 of Set 1 | otradnoye
# Processing record 142 of Set 1 | rybnik
# Processing record 143 of Set 1 | souillac
# Processing record 144 of Set 1 | xai-xai
# Processing record 145 of Set 1 | apateu
# Processing record 146 of Set 1 | aksu
# Processing record 147 of Set 1 | jamestown
# Processing record 148 of Set 1 | mindelo
# Processing record 149 of Set 1 | waingapu
# Processing record 150 of Set 1 | vostok
# Processing record 151 of Set 1 | wamba
# Processing record 152 of Set 1 | puerto narino
# Processing record 153 of Set 1 | kudahuvadhoo
# Processing record 154 of Set 1 | port elizabeth
# Processing record 155 of Set 1 | tuatapere
# Processing record 156 of Set 1 | codrington
# Processing record 157 of Set 1 | port hardy
# Processing record 158 of Set 1 | necochea
# Processing record 159 of Set 1 | dubbo
# Processing record 160 of Set 1 | lebu
# Processing record 161 of Set 1 | longonjo
# Processing record 162 of Set 1 | okhotsk
# Record not found
# Processing record 163 of Set 1 | cherskiy
# Processing record 164 of Set 1 | washington
# Processing record 165 of Set 1 | fortuna
# Processing record 166 of Set 1 | diamantino
# Processing record 167 of Set 1 | escanaba
# Processing record 168 of Set 1 | marzuq
# Processing record 169 of Set 1 | den helder
# Processing record 170 of Set 1 | saint-philippe
# Processing record 171 of Set 1 | clyde river
# Processing record 172 of Set 1 | cabo san lucas
# Processing record 173 of Set 1 | ahipara
# Processing record 174 of Set 1 | mahebourg
# Processing record 175 of Set 1 | lata
# Processing record 176 of Set 1 | solton
# Processing record 177 of Set 1 | bani
# Processing record 178 of Set 1 | sioux lookout
# Processing record 179 of Set 1 | longyearbyen
# Processing record 180 of Set 1 | arlit
# Processing record 181 of Set 1 | tuktoyaktuk
# Processing record 182 of Set 1 | tura
# Processing record 183 of Set 1 | dunedin
# Processing record 184 of Set 1 | iringa
# Processing record 185 of Set 1 | ankpa
# Record not found
# Processing record 186 of Set 1 | megion
# Processing record 187 of Set 1 | abu kamal
# Processing record 188 of Set 1 | khandagayty
# Processing record 189 of Set 1 | sao joao da barra
# Processing record 190 of Set 1 | buchanan
# Processing record 191 of Set 1 | taoudenni
# Processing record 192 of Set 1 | laguna
# Processing record 193 of Set 1 | rio grande
# Processing record 194 of Set 1 | russell
# Processing record 195 of Set 1 | saskylakh
# Processing record 196 of Set 1 | rocha
# Processing record 197 of Set 1 | ambulu
# Processing record 198 of Set 1 | beira
# Processing record 199 of Set 1 | tarakan
# Processing record 200 of Set 1 | broome
# Processing record 201 of Set 1 | faya
# Record not found
# Record not found
# Processing record 202 of Set 1 | ostrovnoy
# Record not found
# Processing record 203 of Set 1 | mehamn
# Processing record 204 of Set 1 | carballo
# Processing record 205 of Set 1 | nanjangud
# Processing record 206 of Set 1 | yumen
# Processing record 207 of Set 1 | novyy urgal
# Processing record 208 of Set 1 | tynda
# Processing record 209 of Set 1 | ilulissat
# Processing record 210 of Set 1 | mallow
# Processing record 211 of Set 1 | buraydah
# Processing record 212 of Set 1 | terme
# Processing record 213 of Set 1 | itambacuri
# Processing record 214 of Set 1 | dalvik
# Processing record 215 of Set 1 | deputatskiy
# Processing record 216 of Set 1 | paita
# Processing record 217 of Set 1 | solano
# Processing record 218 of Set 1 | lavrentiya
# Record not found
# Processing record 219 of Set 1 | rumford
# Processing record 220 of Set 1 | sao filipe
# Processing record 221 of Set 1 | poum
# Processing record 222 of Set 1 | teya
# Processing record 223 of Set 1 | wanaka
# Record not found
# Record not found
# Processing record 224 of Set 1 | bilibino
# Processing record 225 of Set 1 | guerrero negro
# Processing record 226 of Set 1 | ouallam
# Processing record 227 of Set 1 | ponta do sol
# Processing record 228 of Set 1 | san policarpo
# Processing record 229 of Set 1 | kawalu
# Processing record 230 of Set 1 | uray
# Processing record 231 of Set 1 | torbay
# Processing record 232 of Set 1 | krasnoselkup
# Record not found
# Processing record 233 of Set 1 | chapais
# Processing record 234 of Set 1 | matara
# Processing record 235 of Set 1 | kununurra
# Processing record 236 of Set 1 | paamiut
# Processing record 237 of Set 1 | barguzin
# Processing record 238 of Set 1 | tierralta
# Processing record 239 of Set 1 | saldanha
# Processing record 240 of Set 1 | luderitz
# Record not found
# Processing record 241 of Set 1 | arivonimamo
# Processing record 242 of Set 1 | port-gentil
# Processing record 243 of Set 1 | lake cowichan
# Processing record 244 of Set 1 | manakara
# Processing record 245 of Set 1 | iracoubo
# Processing record 246 of Set 1 | srednekolymsk
# Processing record 247 of Set 1 | tual
# Processing record 248 of Set 1 | khatanga
# Processing record 249 of Set 1 | hun
# Record not found
# Processing record 250 of Set 1 | anuppur
# Processing record 251 of Set 1 | mareeba
# Processing record 252 of Set 1 | la paz
# Processing record 253 of Set 1 | ozernovskiy
# Processing record 254 of Set 1 | eureka
# Processing record 255 of Set 1 | broken hill
# Processing record 256 of Set 1 | klaebu
# Processing record 257 of Set 1 | clyde
# Processing record 258 of Set 1 | mattru
# Processing record 259 of Set 1 | muisne
# Processing record 260 of Set 1 | alexandria
# Processing record 261 of Set 1 | sainte-anne-des-monts
# Processing record 262 of Set 1 | mabaruma
# Processing record 263 of Set 1 | waipawa
# Processing record 264 of Set 1 | watertown
# Processing record 265 of Set 1 | san patricio
# Processing record 266 of Set 1 | langsa
# Processing record 267 of Set 1 | ternate
# Processing record 268 of Set 1 | turukhansk
# Processing record 269 of Set 1 | slobozia
# Processing record 270 of Set 1 | cayenne
# Processing record 271 of Set 1 | tabou
# Processing record 272 of Set 1 | amod
# Processing record 273 of Set 1 | kidal
# Processing record 274 of Set 1 | filadelfia
# Processing record 275 of Set 1 | melilla
# Processing record 276 of Set 1 | vuktyl
# Processing record 277 of Set 1 | culfa
# Record not found
# Processing record 278 of Set 1 | namatanai
# Processing record 279 of Set 1 | jawhar
# Processing record 280 of Set 1 | dikson
# Processing record 281 of Set 1 | malartic
# Processing record 282 of Set 1 | tilichiki
# Processing record 283 of Set 1 | coruripe
# Processing record 284 of Set 1 | provideniya
# Processing record 285 of Set 1 | khash
# Processing record 286 of Set 1 | ucluelet
# Processing record 287 of Set 1 | wanning
# Processing record 288 of Set 1 | finschhafen
# Processing record 289 of Set 1 | cerritos
# Processing record 290 of Set 1 | bengkulu
# Processing record 291 of Set 1 | neiafu
# Processing record 292 of Set 1 | labuhan
# Processing record 293 of Set 1 | pierre
# Processing record 294 of Set 1 | snasa
# Processing record 295 of Set 1 | sisimiut
# Processing record 296 of Set 1 | massaguet
# Processing record 297 of Set 1 | cap malheureux
# Record not found
# Processing record 298 of Set 1 | beaverlodge
# Processing record 299 of Set 1 | aykhal
# Processing record 300 of Set 1 | chuy
# Processing record 301 of Set 1 | yagodnoye
# Processing record 302 of Set 1 | ossora
# Processing record 303 of Set 1 | san quintin
# Processing record 304 of Set 1 | balaipungut
# Processing record 305 of Set 1 | jiwani
# Processing record 306 of Set 1 | hasaki
# Record not found
# Processing record 307 of Set 1 | pisco
# Processing record 308 of Set 1 | anjozorobe
# Processing record 309 of Set 1 | sri aman
# Processing record 310 of Set 1 | palmer
# Processing record 311 of Set 1 | tulun
# Processing record 312 of Set 1 | egvekinot
# Processing record 313 of Set 1 | clarksburg
# Processing record 314 of Set 1 | chicholi
# Record not found
# Record not found
# Processing record 315 of Set 1 | amberley
# Processing record 316 of Set 1 | margate
# Processing record 317 of Set 1 | tulsipur
# Record not found
# Processing record 318 of Set 1 | makakilo city
# Record not found
# Processing record 319 of Set 1 | sabang
# Processing record 320 of Set 1 | westport
# Processing record 321 of Set 1 | balkanabat
# Processing record 322 of Set 1 | te anau
# Processing record 323 of Set 1 | general roca
# Processing record 324 of Set 1 | dekar
# Processing record 325 of Set 1 | port lincoln
# Processing record 326 of Set 1 | nieuw amsterdam
# Record not found
# Processing record 327 of Set 1 | klyuchi
# Processing record 328 of Set 1 | nome
# Processing record 329 of Set 1 | bubaque
# Record not found
# Processing record 330 of Set 1 | puerto colombia
# Processing record 331 of Set 1 | murray bridge
# Processing record 332 of Set 1 | leningradskiy
# Processing record 333 of Set 1 | grajewo
# Processing record 334 of Set 1 | praia da vitoria
# Processing record 335 of Set 1 | bodmin
# Processing record 336 of Set 1 | portland
# Processing record 337 of Set 1 | vung tau
# Processing record 338 of Set 1 | coquimbo
# Processing record 339 of Set 1 | imbituba
# Processing record 340 of Set 1 | telenesti
# Processing record 341 of Set 1 | aklavik
# Processing record 342 of Set 1 | lahat
# Processing record 343 of Set 1 | ixtapa
# Processing record 344 of Set 1 | east london
# Processing record 345 of Set 1 | balikpapan
# Processing record 346 of Set 1 | sakakah
# Processing record 347 of Set 1 | college
# Processing record 348 of Set 1 | nabire
# Processing record 349 of Set 1 | narsaq
# Processing record 350 of Set 1 | tiksi
# Processing record 351 of Set 1 | leshukonskoye
# Processing record 352 of Set 1 | aquiraz
# Processing record 353 of Set 1 | grand gaube
# Processing record 354 of Set 1 | grafenau
# Processing record 355 of Set 1 | ohara
# Record not found
# Processing record 356 of Set 1 | kollam
# Processing record 357 of Set 1 | paciran
# Processing record 358 of Set 1 | tabas
# Processing record 359 of Set 1 | tukrah
# Processing record 360 of Set 1 | orlik
# Processing record 361 of Set 1 | klaksvik
# Processing record 362 of Set 1 | coihaique
# Record not found
# Processing record 363 of Set 1 | aasiaat
# Record not found
# Processing record 364 of Set 1 | auki
# Processing record 365 of Set 1 | vila
# Processing record 366 of Set 1 | gunjur
# Processing record 367 of Set 1 | yerbogachen
# Processing record 368 of Set 1 | ulaanbaatar
# Processing record 369 of Set 1 | jinchang
# Processing record 370 of Set 1 | chunskiy
# Processing record 371 of Set 1 | san luis
# Processing record 372 of Set 1 | banda aceh
# Processing record 373 of Set 1 | esna
# Processing record 374 of Set 1 | palana
# Processing record 375 of Set 1 | dallas
# Record not found
# Processing record 376 of Set 1 | hima
# Processing record 377 of Set 1 | ranong
# Processing record 378 of Set 1 | pudozh
# Processing record 379 of Set 1 | kodiak
# Processing record 380 of Set 1 | nouadhibou
# Processing record 381 of Set 1 | nioro
# Processing record 382 of Set 1 | new ulm
# Processing record 383 of Set 1 | rudnya
# Processing record 384 of Set 1 | dingle
# Processing record 385 of Set 1 | komsomolskiy
# Processing record 386 of Set 1 | ust-maya
# Processing record 387 of Set 1 | aloleng
# Processing record 388 of Set 1 | jalu
# Processing record 389 of Set 1 | agadez
# Processing record 390 of Set 1 | phan thiet
# Processing record 391 of Set 1 | havoysund
# Processing record 392 of Set 1 | khanpur
# Processing record 393 of Set 1 | cockburn town
# Processing record 394 of Set 1 | ipixuna
# Processing record 395 of Set 1 | taywarah
# Processing record 396 of Set 1 | key west
# Processing record 397 of Set 1 | shimoda
# Processing record 398 of Set 1 | sai buri
# Processing record 399 of Set 1 | saint-francois
# Record not found
# Record not found
# Processing record 400 of Set 1 | khandbari
# Processing record 401 of Set 1 | naron
# Processing record 402 of Set 1 | san pedro
# Processing record 403 of Set 1 | ryotsu
# Processing record 404 of Set 1 | richards bay
# Processing record 405 of Set 1 | zyryanka
# Processing record 406 of Set 1 | yershov
# Processing record 407 of Set 1 | yining
# Processing record 408 of Set 1 | carutapera
# Processing record 409 of Set 1 | gat
# Processing record 410 of Set 1 | constitucion
# Processing record 411 of Set 1 | ati
# Processing record 412 of Set 1 | pangnirtung
# Processing record 413 of Set 1 | galveston
# Processing record 414 of Set 1 | gizo
# Record not found
# Processing record 415 of Set 1 | okmulgee
# Record not found
# Processing record 416 of Set 1 | pimentel
# Processing record 417 of Set 1 | muli
# Processing record 418 of Set 1 | kaseda
# Processing record 419 of Set 1 | bitkine
# Processing record 420 of Set 1 | bam
# Processing record 421 of Set 1 | talnakh
# Processing record 422 of Set 1 | raudeberg
# Processing record 423 of Set 1 | inyonga
# Processing record 424 of Set 1 | gushikawa
# Processing record 425 of Set 1 | katima mulilo
# Processing record 426 of Set 1 | kadoma
# Processing record 427 of Set 1 | durango
# Record not found
# Processing record 428 of Set 1 | ust-kuyga
# Processing record 429 of Set 1 | adrar
# Processing record 430 of Set 1 | nerchinskiy zavod
# Processing record 431 of Set 1 | wattegama
# Processing record 432 of Set 1 | pontes e lacerda
# Processing record 433 of Set 1 | thunder bay
# Processing record 434 of Set 1 | kargasok
# Processing record 435 of Set 1 | itanhem
# Processing record 436 of Set 1 | kaliganj
# Record not found
# Processing record 437 of Set 1 | nanortalik
# Processing record 438 of Set 1 | north platte
# Processing record 439 of Set 1 | panukulan
# Record not found
# Processing record 440 of Set 1 | fuerte olimpo
# Processing record 441 of Set 1 | tondano
# Processing record 442 of Set 1 | oranjemund
# Processing record 443 of Set 1 | ayan
# Processing record 444 of Set 1 | chicama
# Processing record 445 of Set 1 | petropavlovsk-kamchatskiy
# Processing record 446 of Set 1 | bijar
# Processing record 447 of Set 1 | baghpat
# Processing record 448 of Set 1 | amahai
# Processing record 449 of Set 1 | babusnica
# Processing record 450 of Set 1 | saint-pierre
# Processing record 451 of Set 1 | nara
# Processing record 452 of Set 1 | coahuayana
# Processing record 453 of Set 1 | muyezerskiy
# Processing record 454 of Set 1 | sao jose da coroa grande
# Processing record 455 of Set 1 | zhigansk
# Processing record 456 of Set 1 | sept-iles
# Processing record 457 of Set 1 | muros
# Processing record 458 of Set 1 | moengo
# Record not found
# Processing record 459 of Set 1 | flin flon
# Processing record 460 of Set 1 | guarapari
# Processing record 461 of Set 1 | ceres
# Processing record 462 of Set 1 | tambovka
# Processing record 463 of Set 1 | erzin
# Processing record 464 of Set 1 | holme
# Processing record 465 of Set 1 | ekhabi
# Processing record 466 of Set 1 | magdagachi
# Processing record 467 of Set 1 | tooele
# Processing record 468 of Set 1 | clarksdale
# Processing record 469 of Set 1 | mount gambier
# Record not found
# Processing record 470 of Set 1 | dalby
# Processing record 471 of Set 1 | markova
# Processing record 472 of Set 1 | olga
# Processing record 473 of Set 1 | port keats
# Processing record 474 of Set 1 | vila velha
# Record not found
# Processing record 475 of Set 1 | kangaatsiaq
# Processing record 476 of Set 1 | cabedelo
# Processing record 477 of Set 1 | arti
# Processing record 478 of Set 1 | marsh harbour
# Processing record 479 of Set 1 | dubuque
# Processing record 480 of Set 1 | fredericksburg
# Record not found
# Processing record 481 of Set 1 | pathankot
# Processing record 482 of Set 1 | katherine
# Processing record 483 of Set 1 | padang
# Processing record 484 of Set 1 | victoria
# Processing record 485 of Set 1 | ornskoldsvik
# Processing record 486 of Set 1 | wladyslawowo
# Processing record 487 of Set 1 | nakusp
# Processing record 488 of Set 1 | mildura
# Processing record 489 of Set 1 | havre-saint-pierre
# Record not found
# Processing record 490 of Set 1 | ayagoz
# Processing record 491 of Set 1 | marawi
# Processing record 492 of Set 1 | herat
# Processing record 493 of Set 1 | toronto
# Record not found
# Processing record 494 of Set 1 | ismailia
# Processing record 495 of Set 1 | rantepao
# Processing record 496 of Set 1 | minchinabad
# Processing record 497 of Set 1 | fremont
# Processing record 498 of Set 1 | raipur
# Processing record 499 of Set 1 | miraflores
# Processing record 500 of Set 1 | graaff-reinet
# Processing record 501 of Set 1 | alofi
# Processing record 502 of Set 1 | shaunavon
# Processing record 503 of Set 1 | pokhara
# Processing record 504 of Set 1 | kruisfontein
# Processing record 505 of Set 1 | willmar
# Record not found
# Processing record 506 of Set 1 | nizwa
# Processing record 507 of Set 1 | clarence town
# Processing record 508 of Set 1 | marsa matruh
# Processing record 509 of Set 1 | emerald
# Processing record 510 of Set 1 | nagorsk
# Processing record 511 of Set 1 | primo tapia
# Processing record 512 of Set 1 | khandyga
# Processing record 513 of Set 1 | mahajanga
# Processing record 514 of Set 1 | beringovskiy
# Processing record 515 of Set 1 | plettenberg bay
# Processing record 516 of Set 1 | touros
# Processing record 517 of Set 1 | kodinsk
# Processing record 518 of Set 1 | sovetskiy
# Processing record 519 of Set 1 | hirtshals
# Processing record 520 of Set 1 | havelock
# Processing record 521 of Set 1 | abu samrah
# Processing record 522 of Set 1 | port hueneme
# Processing record 523 of Set 1 | ilam
# Processing record 524 of Set 1 | bahadurganj
# Record not found
# Record not found
# Processing record 525 of Set 1 | kirakira
# Processing record 526 of Set 1 | isiro
# Processing record 527 of Set 1 | tsubata
# Processing record 528 of Set 1 | cuamba
# Processing record 529 of Set 1 | dali
# Processing record 530 of Set 1 | sorong
# Processing record 531 of Set 1 | naryan-mar
# Processing record 532 of Set 1 | brae
# Processing record 533 of Set 1 | san miguel
# Processing record 534 of Set 1 | goderich
# Record not found
# Record not found
# Processing record 535 of Set 1 | rehoboth
# Processing record 536 of Set 1 | entre rios
# Processing record 537 of Set 1 | santa cruz
# Processing record 538 of Set 1 | jambi
# Record not found
# Processing record 539 of Set 1 | oshogbo
# Processing record 540 of Set 1 | ipu
# Processing record 541 of Set 1 | beaufort
# Processing record 542 of Set 1 | golden
# Processing record 543 of Set 1 | half moon bay
# Processing record 544 of Set 1 | xuanhua
# Record not found
# Processing record 545 of Set 1 | usinsk
# Processing record 546 of Set 1 | harwich
# Processing record 547 of Set 1 | lusambo
# Processing record 548 of Set 1 | sur
# Record not found

# %%
# Convert array of JSONs into Pandas DataFrame

weather_dict = {"City": cityname,"Latitude": lat, "Longitude":lng,
                "Max Temp":max_temp,"Humidity":humidity,"Cloudiness":cloudiness,
                "Wind Speed":wind_speed,"Country":country, "Date":date}
weather_data = pd.DataFrame(weather_dict)

# %%
weather_data.head()
# Out:
#               City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0   Ribeira Grande   38.5167   -28.7000     71.82        84           0
# 1         Berlevåg   70.8578    29.0864     48.31        90          95
# 2     Punta Arenas  -53.1500   -70.9167     39.90        76         100
# 3  Mnogovershinnyy   53.9353   139.9242     56.91        69          97
# 4        Bathsheba   13.2167   -59.5167     81.59        80          66
#
#    Wind Speed Country        Date
# 0       11.79      PT  1596434400
# 1        9.53      NO  1596434400
# 2       19.62      CL  1596434400
# 3        7.67      RU  1596434400
# 4       12.01      BB  1596434400

# %%
weather_dict = {
    "City": cityname,
    "Cloudiness" : cloudiness,
    "Country" : country,
    "Date" : date,
    "Humidity" : humidity,
    "Temp": max_temp,
    "Lat" : lat,
    "Lng" : lng,   
    "Wind Speed" : wind_speed
}
weather_data = pd.DataFrame(weather_dict)
weather_data.count()
# Out:
# City          548
# Cloudiness    548
# Country       548
# Date          548
# Humidity      548
# Temp          548
# Lat           548
# Lng           548
# Wind Speed    548
# dtype: int64

# %%
weather_data.head()
# Out:
#               City  Cloudiness Country        Date  Humidity   Temp      Lat  \
# 0   Ribeira Grande           0      PT  1596434400        84  71.82  38.5167
# 1         Berlevåg          95      NO  1596434400        90  48.31  70.8578
# 2     Punta Arenas         100      CL  1596434400        76  39.90 -53.1500
# 3  Mnogovershinnyy          97      RU  1596434400        69  56.91  53.9353
# 4        Bathsheba          66      BB  1596434400        80  81.59  13.2167
#
#         Lng  Wind Speed
# 0  -28.7000       11.79
# 1   29.0864        9.53
# 2  -70.9167       19.62
# 3  139.9242        7.67
# 4  -59.5167       12.01

# %%
# output data to csv
weather_data.to_csv("../output_data/new_city_weather.csv")

# %%
#Plot latitude vs temperature
plt.scatter(weather_data['Lat'], weather_data['Temp'])
plt.title(f'City Latitude vs. Max Temperature')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.grid(True)
plt.savefig('../Images/lat vs temp.png', bbox_inches='tight')

# %%
#Plot latitude vs humidity and save as .png
plt.scatter(weather_data['Lat'],weather_data['Humidity'])
plt.title(f'City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)
plt.savefig('../Images/lat vs humid.png', bbox_inches='tight')

# %%
#Plot latitude vs cloudiness and save as .png
plt.scatter(weather_data['Lat'], weather_data['Cloudiness'])
plt.title(f'City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)
plt.savefig('../Images/lat vs cloud.png', bbox_inches='tight')

# %%
#Plot latitude vs Wind speed and save as .png
plt.scatter(weather_data['Lat'], weather_data['Wind Speed'])
plt.title(f'City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)
plt.savefig('../Images/lat vs windspeed.png', bbox_inches='tight')

# %%
northern_hemisphere = weather_data.loc[weather_data["Lat"] >= 0]
southern_hemisphere = weather_data.loc[weather_data["Lat"] < 0]

# %%
def linear_agression(x,y):
    print(f"The r-squared is : {round(st.pearsonr(x, y)[0],2)}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    return line_eq

# Define a fuction for annotating
def annotate(line_eq, a, b):
    plt.annotate(line_eq,(a,b),fontsize=15,color="red")

# %%
#Northern Hemisphere - Max Temp vs. Latitude Linear Regression

equation = linear_agression(northern_hemisphere["Lat"],northern_hemisphere["Temp"])
annotate(equation, 0, 50)

# Set a title
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")

# Set x and y label
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")

plt.savefig("../Images/Northern Hemisphere - Max Temp vs. Latitude.png")
# Out:
# The r-squared is : -0.68

# %%
#Southern Hemisphere - Max Temp vs. Latitude Linear Regression

equation = linear_agression(southern_hemisphere["Lat"],southern_hemisphere["Temp"])
annotate(equation, -30, 40)

# Set a title
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")

# Set x and y label
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")

plt.savefig("../Images/Southern Hemisphere - Max Temp vs. Latitude.png")
# Out:
# The r-squared is : 0.76

# %%
#Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Humidity"])
annotate(equation, 45, 10)
#Set title
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

#Set x and y label
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

plt.savefig("../Images/Northern Hemisphere - Humidity vs. Latitude.png")
# Out:
# The r-squared is : 0.01

# %%
#Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Humidity"])
annotate(equation, -55, 30)
#set Title 
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
#Set x and y label
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

plt.savefig("../Images/Southern Hemisphere - Humidity vs. Latitude.png")
# Out:
# The r-squared is : 0.05

# %%
#Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Cloudiness"])
annotate(equation, 30, 40)

# Set a title
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# Set x and y labels
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

plt.savefig("../Images/Northern Hemisphere - Cloudiness vs. Latitude.png")
# Out:
# The r-squared is : -0.03

# %%
#Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Cloudiness"])
annotate(equation,-50, 10)

# Set a title
plt.title("southern_hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# Set x and y labels
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")


plt.savefig("../Images/Southern Hemisphere - Cloudiness vs. Latitude.png")
# Out:
# The r-squared is : -0.17

# %%
#Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Wind Speed"])
annotate(equation, 40, 35)

# Set a title
plt.title("Northern Hemisphere - Wind speed(mph) (%) vs. Latitude Linear Regression")

# Set x and y labels
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

plt.savefig("../Images/Northern Hemisphere - Wind speed vs. Latitude.png")
# Out:
# The r-squared is : -0.1

# %%
#Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
equation = linear_agression(southern_hemisphere["Lat"],southern_hemisphere["Wind Speed"])
annotate(equation, -25, 25)
# Set a title
plt.title("Southern Hemisphere - Wind speed(mph) (%) vs. Latitude Linear Regression")

# Set x and y labels
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")


plt.savefig("../Images/Southern Hemisphere - Wind speed vs. Latitude.png")
# Out:
# The r-squared is : -0.09
